# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('train.csv')

# %%
train['time']=pd.to_datetime(train['time'])

# %%
train['time']=pd.to_numeric(train['time'])

# %%
train
# Out:
#       id                 time   feature_1     feature_2
# 0      0  1552953600000000000  735.740043  54479.540513
# 1      1  1552953610000000000  734.102947  47888.033714
# 2      2  1552953620000000000  730.060336  47700.882325
# 3      3  1552953630000000000  725.609742  47790.094648
# 4      4  1552953640000000000  724.328480  47808.402381
# ..   ...                  ...         ...           ...
# 559  559  1552959190000000000  423.726707  54115.388787
# 560  560  1552959200000000000  424.278568  54127.830664
# 561  561  1552959210000000000  420.127639  54092.561194
# 562  562  1552959220000000000  421.291993  53994.714950
# 563  563  1552959230000000000  423.257581  53863.615475
#
# [564 rows x 4 columns]

# %%
train_10 = train.head(10)

# %%
train_10
# Out:
#    id                 time   feature_1     feature_2
# 0   0  1552953600000000000  735.740043  54479.540513
# 1   1  1552953610000000000  734.102947  47888.033714
# 2   2  1552953620000000000  730.060336  47700.882325
# 3   3  1552953630000000000  725.609742  47790.094648
# 4   4  1552953640000000000  724.328480  47808.402381
# 5   5  1552953650000000000  723.715893  47810.517411
# 6   6  1552953660000000000  720.406875  47835.758121
# 7   7  1552953670000000000  712.682269  47806.938481
# 8   8  1552953680000000000  711.509741  47812.099044
# 9   9  1552953690000000000  707.025594  47821.540514

# %%
train.shape
# Out:
# (564, 4)

# %%
train_detail = train.describe()

# %%
train_detail
# Out:
#               id          time   feature_1     feature_2
# count  564.00000  5.640000e+02  564.000000    564.000000
# mean   281.50000  1.552956e+18  523.754885  52487.426941
# std    162.95705  1.629570e+12   70.507377   1582.206650
# min      0.00000  1.552954e+18  420.127639  47700.882325
# 25%    140.75000  1.552955e+18  474.970260  51842.916087
# 50%    281.50000  1.552956e+18  501.204656  53170.608346
# 75%    422.25000  1.552958e+18  569.862105  53515.111143
# max    563.00000  1.552959e+18  735.740043  54479.540513

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 564 entries, 0 to 563
# Data columns (total 4 columns):
# id           564 non-null int64
# time         564 non-null int64
# feature_1    564 non-null float64
# feature_2    564 non-null float64
# dtypes: float64(2), int64(2)
# memory usage: 17.8 KB

# %%
correlation = train.corr()

# %%
import seaborn as sns

# %% [raw]
# sns.heatmap(correlation, annot=True,)

# %%
sns.pairplot(train)

# %%
sns.boxenplot(x='feature_1', data=train)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
sns.boxenplot(y='feature_2', data=train)

# %%
sns.jointplot(x='feature_1',y='feature_2',data=train,kind='kde',annot_kws=True)

# %%
sns.jointplot(x='feature_1',y='feature_2',data=train,kind='hex',annot_kws=True)

# %%
sns.jointplot(x='feature_1',y='feature_2',data=train,kind='reg',annot_kws=True)

# %%
sns.jointplot(x='feature_1',y='feature_2',data=train,kind='scatter',annot_kws=True)

# %%
sns.heatmap(train.isnull())

# %%
test = pd.read_csv('test.csv')
sns.heatmap(test.isnull())

# %%
from sklearn.linear_model import LinearRegression

# %%
x,y = train['feature_1'],train['feature_2']
X,Y = pd.DataFrame(x),pd.DataFrame(y)

# %%
X
# Out:
#       feature_1
# 0    735.740043
# 1    734.102947
# 2    730.060336
# 3    725.609742
# 4    724.328480
# ..          ...
# 559  423.726707
# 560  424.278568
# 561  420.127639
# 562  421.291993
# 563  423.257581
#
# [564 rows x 1 columns]

# %%
Y
# Out:
#         feature_2
# 0    54479.540513
# 1    47888.033714
# 2    47700.882325
# 3    47790.094648
# 4    47808.402381
# ..            ...
# 559  54115.388787
# 560  54127.830664
# 561  54092.561194
# 562  53994.714950
# 563  53863.615475
#
# [564 rows x 1 columns]

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# [63497.03890325]
# [[-21.02054279]]

# %%
test['time']=pd.to_datetime(test['time'])

# %%
test_x = test['feature_1']
test_X = pd.DataFrame(x)
test_X
print(np.shape(test_X))
# Out:
# (564, 1)

# %%
test_Y=model.predict(test_X)

# %%
test_Y={'feature_2':test_Y}

# %%
test_Y
# Out:
# {'feature_2': array([[48031.38385646],
#         [48065.7964956 ],
#         [48150.77436205],
#         [48244.3282766 ],
#         [48271.2610858 ],
#         [48284.13801597],
#         [48353.69535388],
#         [48516.07078097],
#         [48540.71794429],
#         [48634.97715259],
#         [48678.23646676],
#         [48817.40477757],
#         [48880.90531606],
#         [48888.60211689],
#         [48925.7114511 ],
#         [49025.62391444],
#         [49026.83753732],
#         [49095.93847305],
#         [49224.97823785],
#         [49241.24469059],
#         [49289.24716068],
#         [49339.98090562],
#         [49327.42108743],
#         [49344.36316252],
#         [49395.77965506],
#         [49469.3008517 ],
#         [49486.69728637],
#         [49477.1896665 ],
#         [49528.40571462],
#         [49606.0051938 ],
#         [49590.55123605],
#         [49594.69213492],
#         [49614.89984835],
#         [49766.19815015],
#         [49746.56847859],
# ...

# %%
text_X = pd.DataFrame(test_X)

# %%
test_X
# Out:
#       feature_1
# 0    735.740043
# 1    734.102947
# 2    730.060336
# 3    725.609742
# 4    724.328480
# ..          ...
# 559  423.726707
# 560  424.278568
# 561  420.127639
# 562  421.291993
# 563  423.257581
#
# [564 rows x 1 columns]

# %%
test_Y=pd.DataFrame(data=test_Y, index(1), columns=1)
# Out:
#   File "<ipython-input-44-8871a444eb16>", line 1
#     test_Y=pd.DataFrame(data=test_Y, index(1), columns=1)
#                                     ^
# SyntaxError: positional argument follows keyword argument

# %%
test_Y
# Out:
# {'feature_2': array([[48031.38385646],
#         [48065.7964956 ],
#         [48150.77436205],
#         [48244.3282766 ],
#         [48271.2610858 ],
#         [48284.13801597],
#         [48353.69535388],
#         [48516.07078097],
#         [48540.71794429],
#         [48634.97715259],
#         [48678.23646676],
#         [48817.40477757],
#         [48880.90531606],
#         [48888.60211689],
#         [48925.7114511 ],
#         [49025.62391444],
#         [49026.83753732],
#         [49095.93847305],
#         [49224.97823785],
#         [49241.24469059],
#         [49289.24716068],
#         [49339.98090562],
#         [49327.42108743],
#         [49344.36316252],
#         [49395.77965506],
#         [49469.3008517 ],
#         [49486.69728637],
#         [49477.1896665 ],
#         [49528.40571462],
#         [49606.0051938 ],
#         [49590.55123605],
#         [49594.69213492],
#         [49614.89984835],
#         [49766.19815015],
#         [49746.56847859],
# ...

# %%
np.shape(result)
# Out:
# (2, 1)

# %%
sns.jointplot(x=test_X,y=test_Y)
