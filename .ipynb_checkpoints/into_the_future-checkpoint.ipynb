# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('train.csv')

# %%
sns.heatmap(test.isnull())train_10 = train.head(10)

# %%
train_10
# Out:
#    id                 time   feature_1     feature_2
# 0   0  2019-03-19 00:00:00  735.740043  54479.540513
# 1   1  2019-03-19 00:00:10  734.102947  47888.033714
# 2   2  2019-03-19 00:00:20  730.060336  47700.882325
# 3   3  2019-03-19 00:00:30  725.609742  47790.094648
# 4   4  2019-03-19 00:00:40  724.328480  47808.402381
# 5   5  2019-03-19 00:00:50  723.715893  47810.517411
# 6   6  2019-03-19 00:01:00  720.406875  47835.758121
# 7   7  2019-03-19 00:01:10  712.682269  47806.938481
# 8   8  2019-03-19 00:01:20  711.509741  47812.099044
# 9   9  2019-03-19 00:01:30  707.025594  47821.540514

# %%
train.shape
# Out:
# (564, 4)

# %%
train_detail = train.describe()

# %%
train_detail
# Out:
#               id   feature_1     feature_2
# count  564.00000  564.000000    564.000000
# mean   281.50000  523.754885  52487.426941
# std    162.95705   70.507377   1582.206650
# min      0.00000  420.127639  47700.882325
# 25%    140.75000  474.970260  51842.916087
# 50%    281.50000  501.204656  53170.608346
# 75%    422.25000  569.862105  53515.111143
# max    563.00000  735.740043  54479.540513

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 564 entries, 0 to 563
# Data columns (total 4 columns):
# id           564 non-null int64
# time         564 non-null object
# feature_1    564 non-null float64
# feature_2    564 non-null float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 17.8+ KB

# %%
correlation = train.corr()

# %%
import seaborn as sns

# %%
sns.heatmap(correlation, annot=True)

# %%
sns.pairplot(train)

# %%
sns.boxenplot(x='feature_1', data=train)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
sns.boxenplot(y='feature_2', data=train)

# %%
sns.jointplot(x='feature_1',y='feature_2',data=train,kind='kde')

# %%
sns.jointplot(x='feature_1',y='feature_2',data=train,kind='hex')

# %%
sns.jointplot(x='feature_1',y='feature_2',data=train,kind='reg')

# %%
sns.jointplot(x='feature_1',y='feature_2',data=train,kind='scatter')

# %%
test = pd.read_csv('test.csv')

# %%
sns.heatmap(train.isnull())

# %%
sns.heatmap(test.isnull())

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
print(model.intercept_)
